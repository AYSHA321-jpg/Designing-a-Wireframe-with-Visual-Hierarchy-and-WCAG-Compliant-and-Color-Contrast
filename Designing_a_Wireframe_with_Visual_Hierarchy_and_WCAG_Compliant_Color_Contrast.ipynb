# %% [markdown]
# #DESIGNING A WIREFRAME WITH  VISUAL HIERARCHY AND WCAG COMPLIANT COLOR
#
#
# 1) Create a low-fidelity wireframe that demonstrates proper visual hierarchy, spacing, contrast, and alignment to ensure readability and usability.
#
# -![paper wireframing .jpg](data:image/jpeg;base64,...)
#
# From the above picture u can see I have Created a low-fidelity wireframe or u can say a paper wireframing of I Phone SE version which shows the lock screen , that demonstrates proper visual hierarchy, spacing, contrast, and alignment to ensure readability and usability.
#
#
# 2) Develop a color palette with at least three primary colors and three secondary colors, ensuring accessibility compliance.
#
# -![color palete for Ui design.jpg](data:image/jpeg;base64,...)
#
# As I am a new  beginner , I just recently know about figma so for me the main color palete is consist of three main colors i.e. primary ,secondary,tertiary as u can see from the above image.
#
# 3) Select a simple UI layout to structure, such as a login screen, dashboard, or product listing page.
#
# -I have taken the login screen of G-PAY as it is easy to understand and use.The UI of G PAY is user interactive ,the color ,aesthetics ,buttons everything is easy and clearly understable.Below is the login screen of GPAY -
# ![gpay UI LAYOUT.jpg](data:image/jpeg;base64,...)
#
#
# 4) Test the readability and accessibility of text elements.
#
# -Readability is the measure of how easy a piece of text is to read.It can include elements of complexity ,familiarity ,legibility and typography .As I have taken the UI of GPAY the  text elements of readability and accessibilty saves time and money as well as boosting profitability and incresing engagement.
#
#
# 5)B Compile findings into a structured submission that includes:
# # A wireframe showcasing visual hierarchy and structure
# # A documented color palette with contrast ratio analysis
# # A brief report explaining the design choices and accessibility considerations
#
#
# -As I have already uploaded the image of wireframe and color palete  in answer 1 and 2 ,from there u can see the structure detail  of the application .
#
# Accessibility in design is a crucial element for creating inclusive environments in both physical and digital spaces. It ensures that everyone, regardless of ability or disability, can access and interact with products, services, and information effectively
